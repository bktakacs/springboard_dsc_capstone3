# %% [markdown]
# ## __Springboard Capstone 3 Project__
# ## ___Ben Takacs___
#
# Running on Python 3.10.4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
datapath = './data/'

# Load Data
df11 = pd.read_excel(datapath + 'Table 01.01.xlsx', skiprows=[1,2,3,4,5,6,7,9], header=[1])

# %%
df11.head()
# Out:
#            Month  Total Fossil Fuels Production  \
# 0   1973 January                       4.932632
# 1  1973 February                       4.729582
# 2     1973 March                       4.946902
# 3     1973 April                       4.716271
# 4       1973 May                       4.956995
#
#    Nuclear Electric Power Production  Total Renewable Energy Production  \
# 0                           0.068103                           0.219839
# 1                           0.064634                           0.197330
# 2                           0.072494                           0.218686
# 3                           0.064070                           0.209330
# 4                           0.062111                           0.215982
#
#    Total Primary Energy Production  Primary Energy Imports  \
# 0                         5.220574                1.173080
# 1                         4.991545                1.168005
# 2                         5.238082                1.309473
# 3                         4.989672                1.085169
# 4                         5.235087                1.162804
#
#    Primary Energy Exports  Primary Energy Net Imports  \
# 0                0.125781                    1.047299
# 1                0.120883                    1.047122
# 2                0.139950                    1.169523
# 3                0.194185                    0.890984
# 4                0.196775                    0.966029
#
#    Primary Energy Stock Change and Other  Total Fossil Fuels Consumption  \
# 0                               0.771858                        6.747651
# 1                               0.390129                        6.163095
# 2                              -0.067640                        6.044647
# 3                              -0.110067                        5.493184
# 4                              -0.305335                        5.613551
#
#    Nuclear Electric Power Consumption  Total Renewable Energy Consumption  \
# 0                            0.068103                            0.219839
# 1                            0.064634                            0.197330
# 2                            0.072494                            0.218686
# 3                            0.064070                            0.209330
# 4                            0.062111                            0.215982
#
#    Total Primary Energy Consumption
# 0                          7.039731
# 1                          6.428796
# 2                          6.339964
# 3                          5.770589
# 4                          5.895781

# %%
df11.describe()
# Out:
#        Total Fossil Fuels Production  Nuclear Electric Power Production  \
# count                     621.000000                         621.000000
# mean                        5.111740                           0.525343
# std                         0.721788                           0.201493
# min                         3.676065                           0.062111
# 25%                         4.693698                           0.346156
# 50%                         4.853799                           0.601894
# 75%                         5.178934                           0.682603
# max                         7.424986                           0.780456
#
#        Total Renewable Energy Production  Total Primary Energy Production  \
# count                         621.000000                       621.000000
# mean                            0.402017                         6.039100
# std                             0.143793                         0.960469
# min                             0.185300                         4.148867
# 25%                             0.310737                         5.436163
# 50%                             0.347154                         5.741493
# 75%                             0.517750                         6.266310
# max                             0.771513                         8.885241
#
#        Primary Energy Imports  Primary Energy Exports  \
# count              621.000000              621.000000
# mean                 1.871248                0.678551
# std                  0.551515                0.639136
# min                  0.710558                0.056798
# 25%                  1.461137                0.313203
# 50%                  1.839729                0.378123
# 75%                  2.263762                0.872185
# max                  3.149640                2.800726
#
#        Primary Energy Net Imports  Primary Energy Stock Change and Other  \
# count                  621.000000                             621.000000
# mean                     1.192697                               0.027496
# std                      0.798532                               0.475026
# min                     -0.947483                              -0.951489
# 25%                      0.816133                              -0.332476
# 50%                      1.169789                              -0.081028
# 75%                      1.726364                               0.307883
# max                      2.741692                               1.551345
#
#        Total Fossil Fuels Consumption  Nuclear Electric Power Consumption  \
# count                      621.000000                          621.000000
# mean                         6.325687                            0.525343
# std                          0.701259                            0.201493
# min                          4.783910                            0.062111
# 25%                          5.817883                            0.346156
# 50%                          6.338503                            0.601894
# 75%                          6.784358                            0.682603
# max                          8.096323                            0.780456
#
#        Total Renewable Energy Consumption  Total Primary Energy Consumption
# count                          621.000000                        621.000000
# mean                             0.399471                          7.259292
# std                              0.139349                          0.918746
# min                              0.185300                          5.241803
# 25%                              0.311155                          6.525237
# 50%                              0.347510                          7.414495
# 75%                              0.517794                          7.914409
# max                              0.758321                          9.339664

# %%
df11.Month = pd.to_datetime(df11.Month, format='%Y %B')
df11.set_index('Month', inplace=True)

# %%
df11.head()
# Out:
#             Total Fossil Fuels Production  Nuclear Electric Power Production  \
# Month
# 1973-01-01                       4.932632                           0.068103
# 1973-02-01                       4.729582                           0.064634
# 1973-03-01                       4.946902                           0.072494
# 1973-04-01                       4.716271                           0.064070
# 1973-05-01                       4.956995                           0.062111
#
#             Total Renewable Energy Production  \
# Month
# 1973-01-01                           0.219839
# 1973-02-01                           0.197330
# 1973-03-01                           0.218686
# 1973-04-01                           0.209330
# 1973-05-01                           0.215982
#
#             Total Primary Energy Production  Primary Energy Imports  \
# Month
# 1973-01-01                         5.220574                1.173080
# 1973-02-01                         4.991545                1.168005
# 1973-03-01                         5.238082                1.309473
# 1973-04-01                         4.989672                1.085169
# 1973-05-01                         5.235087                1.162804
#
#             Primary Energy Exports  Primary Energy Net Imports  \
# Month
# 1973-01-01                0.125781                    1.047299
# 1973-02-01                0.120883                    1.047122
# 1973-03-01                0.139950                    1.169523
# 1973-04-01                0.194185                    0.890984
# 1973-05-01                0.196775                    0.966029
#
#             Primary Energy Stock Change and Other  \
# Month
# 1973-01-01                               0.771858
# 1973-02-01                               0.390129
# 1973-03-01                              -0.067640
# 1973-04-01                              -0.110067
# 1973-05-01                              -0.305335
#
#             Total Fossil Fuels Consumption  \
# Month
# 1973-01-01                        6.747651
# 1973-02-01                        6.163095
# 1973-03-01                        6.044647
# 1973-04-01                        5.493184
# 1973-05-01                        5.613551
#
#             Nuclear Electric Power Consumption  \
# Month
# 1973-01-01                            0.068103
# 1973-02-01                            0.064634
# 1973-03-01                            0.072494
# 1973-04-01                            0.064070
# 1973-05-01                            0.062111
#
#             Total Renewable Energy Consumption  \
# Month
# 1973-01-01                            0.219839
# 1973-02-01                            0.197330
# 1973-03-01                            0.218686
# 1973-04-01                            0.209330
# 1973-05-01                            0.215982
#
#             Total Primary Energy Consumption
# Month
# 1973-01-01                          7.039731
# 1973-02-01                          6.428796
# 1973-03-01                          6.339964
# 1973-04-01                          5.770589
# 1973-05-01                          5.895781

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 621 entries, 1973-01-01 to 2024-09-01
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Total Fossil Fuels Production          621 non-null    float64
#  1   Nuclear Electric Power Production      621 non-null    float64
#  2   Total Renewable Energy Production      621 non-null    float64
#  3   Total Primary Energy Production        621 non-null    float64
#  4   Primary Energy Imports                 621 non-null    float64
#  5   Primary Energy Exports                 621 non-null    float64
#  6   Primary Energy Net Imports             621 non-null    float64
#  7   Primary Energy Stock Change and Other  621 non-null    float64
#  8   Total Fossil Fuels Consumption         621 non-null    float64
#  9   Nuclear Electric Power Consumption     621 non-null    float64
#  10  Total Renewable Energy Consumption     621 non-null    float64
#  11  Total Primary Energy Consumption       621 non-null    float64
# dtypes: float64(12)
# memory usage: 63.1 KB

# %%
for file in os.listdir(datapath):
    if file.endswith('.csv'):
        df = pd.read_csv(datapath + file)
        print(file, '\t\t', df.isnull().sum().sum())
# Out:
# 7-7c.csv 		 0
# 7-5.csv 		 0
# 4-2b.csv 		 0
# 3-1.csv 		 0
# 1-3.csv 		 0
# 1-2.csv 		 0
# 7-7b.csv 		 0
# 7-6.csv 		 0
# 9-9.csv 		 0
# 4-2a.csv 		 0
# 3-2.csv 		 0
# 1-1.csv 		 0
# 9-8.csv 		 0
# 7-7a.csv 		 0
# 5-1.csv 		 0
# 1-13a.csv 		 0
# 1-12.csv 		 0
# 1-5.csv 		 0
# 3-6.csv 		 0
# 7-7d.csv 		 0
# 5-2.csv 		 0
# 1-13b.csv 		 0
# 1-11.csv 		 0
# 3-4.csv 		 0
# 1-6.csv 		 0
# 3-5.csv 		 0
# 7-1.csv 		 0
# 2-2.csv 		 0
# 4-4.csv 		 0
# E1.csv 		 0
# 2-3.csv 		 0
# 9-10.csv 		 0
# E3.csv 		 0
# E2.csv 		 0
# 2-4.csv 		 0
# 3-7b.csv 		 0
# 6-1.csv 		 0
# 4-3.csv 		 0
# 3-7c.csv 		 0
# 2-5.csv 		 0
# 3-7a.csv 		 0
# 4-1.csv 		 0
# 6-3.csv 		 0
# 6-2.csv 		 0
# E4.csv 		 0
# 2-6.csv 		 0
# 7-3a.csv 		 0
# 10-6.csv 		 0
# 3-8b.csv 		 0
# 10-2b.csv 		 0
# 8-1.csv 		 0
# 10-2c.csv 		 0
# 3-8c.csv 		 0
# 7-3b.csv 		 0
# 3-8a.csv 		 0
# 10-5.csv 		 0
# 10-2a.csv 		 0
# 7-3c.csv 		 0
# 7-2c.csv 		 0
# 1-4b.csv 		 0
# 2-1b.csv 		 0
# 1-4c.csv 		 0
# 10-1.csv 		 0
# 7-2b.csv 		 0
# 10-3.csv 		 0
# 1-4a.csv 		 0
# 2-1a.csv 		 0
# F1-.csv 		 0
# 7-2a.csv 		 0
# 9-3.csv 		 0
# 3-3f.csv 		 0
# 10-4a.csv 		 0
# 11-5.csv 		 0
# 11-4.csv 		 0
# 9-2.csv 		 0
# 7-8d.csv 		 0
# 3-3e.csv 		 0
# 10-4b.csv 		 0
# 11-6.csv 		 0
# 11-7.csv 		 0
# 10-4c.csv 		 0
# 3-3d.csv 		 0
# 9-1.csv 		 0
# 9-5.csv 		 0
# 7-8c.csv 		 0
# 11-3.csv 		 0
# 11-2.csv 		 0
# 3-3a.csv 		 0
# 7-8b.csv 		 0
# 9-4.csv 		 0
# 7-4a.csv 		 0
# 7-4c.csv 		 0
# 9-6.csv 		 0
# 3-3c.csv 		 0
# 11-1.csv 		 0
# 3-3b.csv 		 0
# 7-8a.csv 		 0
# 9-7.csv 		 0
# 7-4b.csv 		 0

# %%
df77 = pd.read_csv(datapath + '7-7c.csv')
df77.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 16 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Month                                                                    429 non-null    object
#  1   Coal Commercial Sector, Net Summer Capacity                              429 non-null    object
#  2   Petroleum Commercial Sector, Net Summer Capacity                         429 non-null    object
#  3   Natural Gas Commercial Sector, Net Summer Capacity                       429 non-null    object
#  4   Fossil Fuels Commercial Sector, Net Summer Capacity                      429 non-null    object
#  5   Nuclear Commercial Sector, Net Summer Capacity                           429 non-null    object
#  6   Hydroelectric Pumped Storage Commercial Sector, Net Summer Capacity      429 non-null    object
#  7   Conventional Hydroelectric Power Commercial Sector, Net Summer Capacity  429 non-null    object
#  8   Wood Commercial Sector, Net Summer Capacity                              429 non-null    object
#  9   Waste Commercial Sector, Net Summer Capacity                             429 non-null    object
#  10  Geothermal Commercial Sector, Net Summer Capacity                        429 non-null    object
#  11  Solar Commercial Sector, Net Summer Capacity                             429 non-null    object
#  12  Wind Commercial Sector, Net Summer Capacity                              429 non-null    object
#  13  Renewable Energy Commercial Sector, Net Summer Capacity                  429 non-null    object
#  14  Battery Storage Commercial Sector, Net Summer Capacity                   429 non-null    object
#  15  Total Commercial Sector, Net Summer Capacity                             429 non-null    object
# dtypes: object(16)
# memory usage: 53.8+ KB

# %%
df1 = pd.read_csv('./dataex/1-1.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 621 entries, 0 to 620
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Month                                  621 non-null    object
#  1   Total Fossil Fuels Production          621 non-null    float64
#  2   Nuclear Electric Power Production      621 non-null    float64
#  3   Total Renewable Energy Production      621 non-null    float64
#  4   Total Primary Energy Production        621 non-null    float64
#  5   Primary Energy Imports                 621 non-null    float64
#  6   Primary Energy Exports                 621 non-null    float64
#  7   Primary Energy Net Imports             621 non-null    float64
#  8   Primary Energy Stock Change and Other  621 non-null    float64
#  9   Total Fossil Fuels Consumption         621 non-null    float64
#  10  Nuclear Electric Power Consumption     621 non-null    float64
#  11  Total Renewable Energy Consumption     621 non-null    float64
#  12  Total Primary Energy Consumption       621 non-null    float64
# dtypes: float64(12), object(1)
# memory usage: 63.2+ KB

# %%
# df98 = pd.read_csv(datapath + '9-8.csv', index_col=0)
df98 = pd.read_csv('./dataex/9-8.csv', index_col=0)
df98.set_index(pd.to_datetime(df98.index), inplace=True)

# %%
df98.isnull().sum()
df98.bfill(inplace=True)
df98
# Out:
#             Average Price of Electricity to Ultimate Customers, Residential  \
# Month
# 1976-01-01                                               3.90
# 1976-02-01                                               3.90
# 1976-03-01                                               3.90
# 1976-04-01                                               3.90
# 1976-05-01                                               3.90
# ...                                                       ...
# 2024-05-01                                              16.43
# 2024-06-01                                              16.42
# 2024-07-01                                              16.63
# 2024-08-01                                              16.63
# 2024-09-01                                              16.83
#
#             Average Price of Electricity to Ultimate Customers, Commercial  \
# Month
# 1976-01-01                                               3.70
# 1976-02-01                                               3.70
# 1976-03-01                                               3.70
# 1976-04-01                                               3.70
# 1976-05-01                                               3.70
# ...                                                       ...
# 2024-05-01                                              12.48
# 2024-06-01                                              13.07
# 2024-07-01                                              13.58
# 2024-08-01                                              13.39
# 2024-09-01                                              13.47
#
#             Average Price of Electricity to Ultimate Customers, Industrial  \
# Month
# 1976-01-01                                               2.30
# 1976-02-01                                               2.30
# 1976-03-01                                               2.30
# 1976-04-01                                               2.30
# 1976-05-01                                               2.30
# ...                                                       ...
# 2024-05-01                                               7.88
# 2024-06-01                                               8.40
# 2024-07-01                                               8.81
# 2024-08-01                                               8.72
# 2024-09-01                                               8.51
#
#             Average Price of Electricity to Ultimate Customers, Transportation  \
# Month
# 1976-01-01                                               7.23
# 1976-02-01                                               7.23
# 1976-03-01                                               7.23
# 1976-04-01                                               7.23
# 1976-05-01                                               7.23
# ...                                                       ...
# 2024-05-01                                              12.21
# 2024-06-01                                              12.74
# 2024-07-01                                              13.15
# 2024-08-01                                              13.18
# 2024-09-01                                              13.01
#
#             Average Price of Electricity to Ultimate Customers, Other  \
# Month
# 1976-01-01                                               5.99
# 1976-02-01                                               5.99
# 1976-03-01                                               5.99
# 1976-04-01                                               5.99
# 1976-05-01                                               5.99
# ...                                                       ...
# 2024-05-01                                                NaN
# 2024-06-01                                                NaN
# 2024-07-01                                                NaN
# 2024-08-01                                                NaN
# 2024-09-01                                                NaN
#
#             Average Price of Electricity to Ultimate Customers, Total
# Month
# 1976-01-01                                               3.00
# 1976-02-01                                               3.00
# 1976-03-01                                               3.00
# 1976-04-01                                               3.00
# 1976-05-01                                               3.00
# ...                                                       ...
# 2024-05-01                                              12.55
# 2024-06-01                                              13.23
# 2024-07-01                                              13.76
# 2024-08-01                                              13.61
# 2024-09-01                                              13.47
#
# [585 rows x 6 columns]

# %% [markdown]
# Missing almost a decade of data, so just start from 1990 and go only until 2020, then we can predict for the year 2021

# %%
df98f = df98
df98 = df98['1990-1-1':'2020-12-1']
df98
# Out:
#             Average Price of Electricity to Ultimate Customers, Residential  \
# Month
# 1990-01-01                                               7.17
# 1990-02-01                                               7.48
# 1990-03-01                                               7.57
# 1990-04-01                                               7.69
# 1990-05-01                                               7.96
# ...                                                       ...
# 2020-08-01                                              13.26
# 2020-09-01                                              13.49
# 2020-10-01                                              13.66
# 2020-11-01                                              13.31
# 2020-12-01                                              12.78
#
#             Average Price of Electricity to Ultimate Customers, Commercial  \
# Month
# 1990-01-01                                               6.93
# 1990-02-01                                               7.15
# 1990-03-01                                               7.23
# 1990-04-01                                               7.20
# 1990-05-01                                               7.31
# ...                                                       ...
# 2020-08-01                                              10.90
# 2020-09-01                                              11.02
# 2020-10-01                                              10.72
# 2020-11-01                                              10.53
# 2020-12-01                                              10.41
#
#             Average Price of Electricity to Ultimate Customers, Industrial  \
# Month
# 1990-01-01                                               4.59
# 1990-02-01                                               4.59
# 1990-03-01                                               4.60
# 1990-04-01                                               4.56
# 1990-05-01                                               4.62
# ...                                                       ...
# 2020-08-01                                               7.07
# 2020-09-01                                               7.00
# 2020-10-01                                               6.72
# 2020-11-01                                               6.49
# 2020-12-01                                               6.41
#
#             Average Price of Electricity to Ultimate Customers, Transportation  \
# Month
# 1990-01-01                                               7.23
# 1990-02-01                                               7.23
# 1990-03-01                                               7.23
# 1990-04-01                                               7.23
# 1990-05-01                                               7.23
# ...                                                       ...
# 2020-08-01                                              10.29
# 2020-09-01                                              10.37
# 2020-10-01                                               9.87
# 2020-11-01                                               9.95
# 2020-12-01                                               9.86
#
#             Average Price of Electricity to Ultimate Customers, Other  \
# Month
# 1990-01-01                                               5.99
# 1990-02-01                                               6.14
# 1990-03-01                                               6.24
# 1990-04-01                                               6.54
# 1990-05-01                                               6.38
# ...                                                       ...
# 2020-08-01                                                NaN
# 2020-09-01                                                NaN
# 2020-10-01                                                NaN
# 2020-11-01                                                NaN
# 2020-12-01                                                NaN
#
#             Average Price of Electricity to Ultimate Customers, Total
# Month
# 1990-01-01                                               6.27
# 1990-02-01                                               6.33
# 1990-03-01                                               6.37
# 1990-04-01                                               6.35
# 1990-05-01                                               6.46
# ...                                                       ...
# 2020-08-01                                              11.02
# 2020-09-01                                              10.99
# 2020-10-01                                              10.65
# 2020-11-01                                              10.38
# 2020-12-01                                              10.37
#
# [372 rows x 6 columns]

# %%
y = df98['Average Price of Electricity to Ultimate Customers, Commercial']

plt.figure()
plt.plot(y)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Plot the original data, the trend, the seasonality, and the residuals 
decomp = seasonal_decompose(y, model='additive')

trend = decomp.trend
seasonal = decomp.seasonal
residual = decomp.resid

plt.subplot(411)
plt.plot(y, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residual')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
from statsmodels.tsa.stattools import kpss
kpss(y)
# Out:
# (2.9748602216637945,
#  0.01,
#  11,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# p=0.01, Reject null hypothesis that data is stationary.

# %%
y.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
ylog = np.log(y)
ylog.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
ylogdiff = ylog.diff().dropna()
kpss(ylogdiff)
# Out:
# (0.022657050943023314,
#  0.1,
#  2,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# p=0.1, accept null hypothesis that data are stationary

# %% [markdown]
# ## __Now we do ARIMA stuff__

# %%
# Import mean_squared_error and ARIMA
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima.model import ARIMA

# %%
def arima_mse(data, order):
    split = int(len(data) * 0.8)
    train, test = data[0:split], data[split:]
    past = [x for x in train]

    predictions = list()
    for i in range(len(test)):
        model = ARIMA(past, order=order)
        model_fit = model.fit()
        future = model_fit.forecast()[0]
        predictions.append(future)
        past.append(test[i])

    error = mean_squared_error(test, predictions)
    
    return error

# %%
# Make a function to evaluate different ARIMA models with several different p, d, and q values.
def model_eval(data, pvals, dvals, qvals):
    best_score, best_cfg = float('inf'), None
    for p in pvals:
        for d in dvals:
            for q in qvals:
                order = (p, d, q)
                try:
                    mse = arima_mse(data, order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                    print('ARIMA%s MSE=%.3E' % (order, mse))
                    
                except:
                    continue
    
    print('Best ARIMA%s MSE=%.3E' % (best_cfg, best_score))

# %%
# Now, we choose a couple of values to try for each parameter.
pvals = [x for x in range(0, 3)]
dvals = [x for x in range(0, 3)]
qvals = [x for x in range(0, 3)]

# %%
# Finally, we can find the optimum ARIMA model for our data.
# Nb. this can take a while...!
import warnings
warnings.filterwarnings("ignore")
model_eval(ylog, pvals, dvals, qvals)
# Out:
# ARIMA(0, 0, 0) MSE=4.081E-02
# ARIMA(0, 0, 1) MSE=1.163E-02
# ARIMA(0, 0, 2) MSE=4.212E-03
# ARIMA(0, 1, 0) MSE=3.444E-04
# ARIMA(0, 1, 1) MSE=3.047E-04
# ARIMA(0, 1, 2) MSE=3.176E-04
# ARIMA(0, 2, 0) MSE=4.774E-04
# ARIMA(0, 2, 1) MSE=4.223E-04
# ARIMA(0, 2, 2) MSE=3.082E-04
# ARIMA(1, 0, 0) MSE=3.438E-04
# ARIMA(1, 0, 1) MSE=3.029E-04
# ARIMA(1, 0, 2) MSE=3.177E-04
# ARIMA(1, 1, 0) MSE=3.150E-04
# ARIMA(1, 1, 1) MSE=3.108E-04
# ARIMA(1, 1, 2) MSE=2.969E-04
# ARIMA(1, 2, 0) MSE=4.537E-04
# ARIMA(1, 2, 1) MSE=3.180E-04
# ARIMA(1, 2, 2) MSE=3.142E-04
# ARIMA(2, 0, 0) MSE=3.156E-04
# ARIMA(2, 0, 1) MSE=3.138E-04
# ARIMA(2, 0, 2) MSE=3.178E-04
# ARIMA(2, 1, 0) MSE=3.085E-04
# ARIMA(2, 1, 1) MSE=2.618E-04
# ARIMA(2, 1, 2) MSE=3.193E-04
# ARIMA(2, 2, 0) MSE=4.214E-04
# ARIMA(2, 2, 1) MSE=3.119E-04
# ARIMA(2, 2, 2) MSE=3.168E-04
# Best ARIMA(2, 1, 1) MSE=2.618E-04

# %%
p = 2; d= 1; q = 1
model = ARIMA(ylog, order=(p,d,q))
model_fit = model.fit()
forecast = model_fit.forecast(12)
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                      SARIMAX Results
# ==========================================================================================================================
# Dep. Variable:     Average Price of Electricity to Ultimate Customers, Commercial   No. Observations:                  372
# Model:                                                             ARIMA(2, 1, 1)   Log Likelihood                 945.761
# Date:                                                            Wed, 12 Feb 2025   AIC                          -1883.522
# Time:                                                                    12:29:35   BIC                          -1867.857
# Sample:                                                                01-01-1990   HQIC                         -1877.301
#                                                                      - 12-01-2020
# Covariance Type:                                                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2240      0.063     19.370      0.000       1.100       1.348
# ar.L2         -0.5008      0.051     -9.856      0.000      -0.600      -0.401
# ma.L1         -0.8673      0.042    -20.737      0.000      -0.949      -0.785
# sigma2         0.0004   2.14e-05     16.633      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.18   Jarque-Bera (JB):                20.96
# Prob(Q):                              0.07   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                             0.29
# Prob(H) (two-sided):                  0.75   Kurtosis:                         4.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# This value should much greater than 0, not sure why it is 0.
model_fit.predict()[1]
# Out:
# 1.9358598135604468

# %%
plt.figure(figsize=(10, 6))
plt.plot(ylog, label='Original')
plt.plot(model_fit.predict(), color = 'red', ls='--', label='Predictions')
plt.legend(loc='best')
plt.ylim([ylog.min(), ylog.max()])
plt.show()

# %%
forecast_period = 12 # months
forecast_dates = pd.date_range(start=ylog.index[-1], periods=forecast_period, freq='MS')


# Convert the forecast dates to a dataframe
fut_months = pd.DataFrame(forecast_dates, columns=['Month'])
fut_months['Month'] = pd.to_datetime(fut_months['Month'])
fut_months.set_index('Month', inplace=True)
fut_months['Prediction'] = forecast

plt.figure(figsize=(10, 6))
plt.plot(ylog, label='Original')
plt.plot(pd.concat([ylog, fut_months['Prediction']]), color = 'red', label='Predictions', ls='--')
plt.legend(loc='best')
plt.show()

# %%
plt.figure()
plt.plot(df98f['Average Price of Electricity to Ultimate Customers, Commercial']['1990-1-1':'2021-12-1'], label='Original')
plt.plot(np.exp(pd.concat([ylog, fut_months.Prediction])), ls='--', label='Prediction')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

from functions import *

# %%
df = pd.read_csv('data/df1.csv', index_col=0)

# %%
corrmat = df.corr()

plt.figure(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True, cmap='coolwarm', annot=True)
plt.show()

# %%
corrmat
# Out:
#                                                     Average Price of Electricity to Ultimate Customers, Residential  \
# Average Price of Electricity to Ultimate Custom...                                           1.000000
# Total Renewable Energy Consumption                                                           0.939735
# Total Petroleum Consumed by the Residential Sector                                          -0.509174
#
#                                                     Total Renewable Energy Consumption  \
# Average Price of Electricity to Ultimate Custom...                            0.939735
# Total Renewable Energy Consumption                                            1.000000
# Total Petroleum Consumed by the Residential Sector                           -0.412574
#
#                                                     Total Petroleum Consumed by the Residential Sector
# Average Price of Electricity to Ultimate Custom...                                          -0.509174
# Total Renewable Energy Consumption                                                          -0.412574
# Total Petroleum Consumed by the Residential Sector                                           1.000000

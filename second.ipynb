# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from functions import *

# %%
df38 = load_table_data('3-8a.csv')

df38
# Out:
# Data loaded from: 3-8a.csv
#             Distillate Fuel Oil Consumed by the Residential Sector  \
# Month
# 1973-01-01                                            308.231
# 1973-02-01                                            263.315
# 1973-03-01                                            205.950
# 1973-04-01                                            144.100
# 1973-05-01                                            122.203
# ...                                                       ...
# 2024-05-01                                             28.910
# 2024-06-01                                             24.600
# 2024-07-01                                             17.076
# 2024-08-01                                             14.656
# 2024-09-01                                             24.862
#
#             Propane Consumed by the Residential Sector  \
# Month
# 1973-01-01                                      92.111
# 1973-02-01                                      80.942
# ...

# %%
df38 = df38['Total Petroleum Consumed by the Residential Sector']
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/indexes/datetimes.py:603, in DatetimeIndex.get_loc(self, key)
#     602 try:
# --> 603     parsed, reso = self._parse_with_reso(key)
#     604 except (ValueError, pytz.NonExistentTimeError) as err:
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/indexes/datetimes.py:559, in DatetimeIndex._parse_with_reso(self, label)
#     558 def _parse_with_reso(self, label: str):
# --> 559     parsed, reso = super()._parse_with_reso(label)
#     561     parsed = Timestamp(parsed)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/indexes/datetimelike.py:293, in DatetimeIndexOpsMixin._parse_with_reso(self, label)
#     291     label = str(label)
# --> 293 parsed, reso_str = parsing.parse_datetime_string_with_reso(label, freqstr)
# ...

# %%
df38
# Out:
# Month
# 1973-01-01    436.556
# 1973-02-01    375.287
# 1973-03-01    283.839
# 1973-04-01    205.866
# 1973-05-01    167.675
#                ...
# 2024-05-01     53.691
# 2024-06-01     40.900
# 2024-07-01     31.619
# 2024-08-01     30.332
# 2024-09-01     41.386
# Name: Total Petroleum Consumed by the Residential Sector, Length: 621, dtype: float64

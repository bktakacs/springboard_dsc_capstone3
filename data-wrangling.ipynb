# %% [markdown]
# # __Springboard Data Science Capstone 3 Project__
# # ___Predicting the Price of Energy___
#
# ### __Data Wrangling__
#
# ##### ___Ben Takacs___
# ###### __Python version 3.10.4__

# %% [markdown]
# ### __Imports and File Location__

# %%
import numpy as np
import pandas
import os
import matplotlib.pyplot as plt
from functions import load_table_data

datapath = './data/'

# %% [markdown]
# ### __Load Relevant Tables from Data Set__
#
# 4.3 - Consumption by Sector \
# 9.8 - Average price of electricity to ultimate customers

# %%
df43 = load_table_data('4-3.csv')
df98 = load_table_data('9-8.csv')
# Out:
# Data loaded from: 4-3.csv
# Data loaded from: 9-8.csv

# %% [markdown]
# ### __Table 4.3 - Consumption by Sector__

# %%
print(df43.info(), '\n\n\n', df43.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 621 entries, 1973-01-01 to 2024-09-01
# Data columns (total 12 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Natural Gas Consumed by the Residential Sector                                 621 non-null    float64
#  1   Natural Gas Consumed by the Commercial Sector                                  621 non-null    float64
#  2   Natural Gas Consumed by the Industrial Sector, Lease and Plant Fuel            621 non-null    float64
#  3   Natural Gas Consumed by the Other Industrial Sector, CHP                       429 non-null    float64
#  4   Natural Gas Consumed by the Other Industrial Sector, Non-CHP                   621 non-null    float64
#  5   Natural Gas Consumed by the Other Industrial Sector, Total                     621 non-null    float64
#  6   Natural Gas Consumed by the Industrial Sector, Total                           621 non-null    float64
#  7   Natural Gas Consumed by the Transportation Sector, Pipelines and Distribution  621 non-null    float64
#  8   Natural Gas Consumed by the Transportation Sector, Vehicle Fuel                417 non-null    float64
#  9   Natural Gas Consumed by the Transportation Sector, Total                       621 non-null    float64
#  10  Natural Gas Consumed by the Electric Power Sector                              621 non-null    float64
#  11  Natural Gas Consumption, Total                                                 621 non-null    float64
# dtypes: float64(12)
# memory usage: 63.1 KB
# None
#
#
#  Natural Gas Consumed by the Residential Sector                                     0
# Natural Gas Consumed by the Commercial Sector                                      0
# Natural Gas Consumed by the Industrial Sector, Lease and Plant Fuel                0
# Natural Gas Consumed by the Other Industrial Sector, CHP                         192
# Natural Gas Consumed by the Other Industrial Sector, Non-CHP                       0
# Natural Gas Consumed by the Other Industrial Sector, Total                         0
# Natural Gas Consumed by the Industrial Sector, Total                               0
# Natural Gas Consumed by the Transportation Sector, Pipelines and Distribution      0
# Natural Gas Consumed by the Transportation Sector, Vehicle Fuel                  204
# Natural Gas Consumed by the Transportation Sector, Total                           0
# Natural Gas Consumed by the Electric Power Sector                                  0
# Natural Gas Consumption, Total                                                     0
# dtype: int64

# %% [markdown]
# Focusing on Residential and Commercial sectors, so keep only those columns

# %%
df43 = df43.drop(columns=df43.columns[2:])
df43
# Out:
#             Natural Gas Consumed by the Residential Sector  \
# Month
# 1973-01-01                                         843.900
# 1973-02-01                                         747.331
# 1973-03-01                                         648.504
# 1973-04-01                                         465.867
# 1973-05-01                                         326.313
# ...                                                    ...
# 2024-05-01                                         171.858
# 2024-06-01                                         122.740
# 2024-07-01                                         107.035
# 2024-08-01                                         105.350
# 2024-09-01                                         113.532
#
#             Natural Gas Consumed by the Commercial Sector
# Month
# 1973-01-01                                        392.315
# 1973-02-01                                        394.281
# 1973-03-01                                        310.799
# 1973-04-01                                        231.943
# 1973-05-01                                        174.258
# ...                                                   ...
# 2024-05-01                                        176.062
# 2024-06-01                                        153.302
# 2024-07-01                                        146.175
# 2024-08-01                                        149.161
# 2024-09-01                                        157.511
#
# [621 rows x 2 columns]

# %%
fig = df43.plot()
# fig.legend().set_visible(False)
plt.show()

# %% [markdown]
# See much larger variability in residential sector as compared to commercial

# %% [markdown]
# ### __Table 9.8 - Average Price of Electricity to Ultimate Customers__

# %%
df98
# Out:
#             Average Price of Electricity to Ultimate Customers, Residential  \
# Month
# 1976-01-01                                                NaN
# 1976-02-01                                                NaN
# 1976-03-01                                                NaN
# 1976-04-01                                                NaN
# 1976-05-01                                                NaN
# ...                                                       ...
# 2024-05-01                                              16.43
# 2024-06-01                                              16.42
# 2024-07-01                                              16.63
# 2024-08-01                                              16.63
# 2024-09-01                                              16.83
#
#             Average Price of Electricity to Ultimate Customers, Commercial  \
# Month
# 1976-01-01                                                NaN
# 1976-02-01                                                NaN
# 1976-03-01                                                NaN
# 1976-04-01                                                NaN
# 1976-05-01                                                NaN
# ...                                                       ...
# 2024-05-01                                              12.48
# 2024-06-01                                              13.07
# 2024-07-01                                              13.58
# 2024-08-01                                              13.39
# 2024-09-01                                              13.47
#
#             Average Price of Electricity to Ultimate Customers, Industrial  \
# Month
# 1976-01-01                                                NaN
# 1976-02-01                                                NaN
# 1976-03-01                                                NaN
# 1976-04-01                                                NaN
# 1976-05-01                                                NaN
# ...                                                       ...
# 2024-05-01                                               7.88
# 2024-06-01                                               8.40
# 2024-07-01                                               8.81
# 2024-08-01                                               8.72
# 2024-09-01                                               8.51
#
#             Average Price of Electricity to Ultimate Customers, Transportation  \
# Month
# 1976-01-01                                                NaN
# 1976-02-01                                                NaN
# 1976-03-01                                                NaN
# 1976-04-01                                                NaN
# 1976-05-01                                                NaN
# ...                                                       ...
# 2024-05-01                                              12.21
# 2024-06-01                                              12.74
# 2024-07-01                                              13.15
# 2024-08-01                                              13.18
# 2024-09-01                                              13.01
#
#             Average Price of Electricity to Ultimate Customers, Other  \
# Month
# 1976-01-01                                                NaN
# 1976-02-01                                                NaN
# 1976-03-01                                                NaN
# 1976-04-01                                                NaN
# 1976-05-01                                                NaN
# ...                                                       ...
# 2024-05-01                                                NaN
# 2024-06-01                                                NaN
# 2024-07-01                                                NaN
# 2024-08-01                                                NaN
# 2024-09-01                                                NaN
#
#             Average Price of Electricity to Ultimate Customers, Total
# Month
# 1976-01-01                                                NaN
# 1976-02-01                                                NaN
# 1976-03-01                                                NaN
# 1976-04-01                                                NaN
# 1976-05-01                                                NaN
# ...                                                       ...
# 2024-05-01                                              12.55
# 2024-06-01                                              13.23
# 2024-07-01                                              13.76
# 2024-08-01                                              13.61
# 2024-09-01                                              13.47
#
# [585 rows x 6 columns]

# %%
print(df98.info())
print(df98.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 585 entries, 1976-01-01 to 2024-09-01
# Data columns (total 6 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Average Price of Electricity to Ultimate Customers, Residential     507 non-null    float64
#  1   Average Price of Electricity to Ultimate Customers, Commercial      507 non-null    float64
#  2   Average Price of Electricity to Ultimate Customers, Industrial      507 non-null    float64
#  3   Average Price of Electricity to Ultimate Customers, Transportation  261 non-null    float64
#  4   Average Price of Electricity to Ultimate Customers, Other           156 non-null    float64
#  5   Average Price of Electricity to Ultimate Customers, Total           507 non-null    float64
# dtypes: float64(6)
# memory usage: 32.0 KB
# None
# Average Price of Electricity to Ultimate Customers, Residential        78
# Average Price of Electricity to Ultimate Customers, Commercial         78
# Average Price of Electricity to Ultimate Customers, Industrial         78
# Average Price of Electricity to Ultimate Customers, Transportation    324
# Average Price of Electricity to Ultimate Customers, Other             429
# Average Price of Electricity to Ultimate Customers, Total              78
# dtype: int64

# %%
# Check what total column is
today = '2024-07-01'
df98.loc[today]
print(df98.drop(columns=df98.columns[-2:]).loc[today].mean())
print(df98['Average Price of Electricity to Ultimate Customers, Total'].loc[today])
# Out:
# 13.0425
# 13.76

# %% [markdown]
# Total column is not an average of other columns

# %%
df98 = df98.drop(columns=df98.columns[2:])
df98
# Out:
#             Average Price of Electricity to Ultimate Customers, Residential  \
# Month
# 1976-01-01                                                NaN
# 1976-02-01                                                NaN
# 1976-03-01                                                NaN
# 1976-04-01                                                NaN
# 1976-05-01                                                NaN
# ...                                                       ...
# 2024-05-01                                              16.43
# 2024-06-01                                              16.42
# 2024-07-01                                              16.63
# 2024-08-01                                              16.63
# 2024-09-01                                              16.83
#
#             Average Price of Electricity to Ultimate Customers, Commercial
# Month
# 1976-01-01                                                NaN
# 1976-02-01                                                NaN
# 1976-03-01                                                NaN
# 1976-04-01                                                NaN
# 1976-05-01                                                NaN
# ...                                                       ...
# 2024-05-01                                              12.48
# 2024-06-01                                              13.07
# 2024-07-01                                              13.58
# 2024-08-01                                              13.39
# 2024-09-01                                              13.47
#
# [585 rows x 2 columns]

# %%
plt.figure()
df98.plot()
plt.grid(True)
plt.show()

# %% [markdown]
# Just take data from beyond ~1989

# %%
df98[('1989-1-1' < df98.index) & (df98.index < '1991-1-1')]
# Out:
#             Average Price of Electricity to Ultimate Customers, Residential  \
# Month
# 1989-02-01                                                NaN
# 1989-03-01                                                NaN
# 1989-04-01                                                NaN
# 1989-05-01                                                NaN
# 1989-06-01                                                NaN
# 1989-07-01                                                NaN
# 1989-08-01                                                NaN
# 1989-09-01                                                NaN
# 1989-10-01                                                NaN
# 1989-11-01                                                NaN
# 1989-12-01                                                NaN
# 1990-01-01                                               7.17
# 1990-02-01                                               7.48
# 1990-03-01                                               7.57
# 1990-04-01                                               7.69
# 1990-05-01                                               7.96
# 1990-06-01                                               8.10
# 1990-07-01                                               8.18
# 1990-08-01                                               8.24
# 1990-09-01                                               8.15
# 1990-10-01                                               8.04
# 1990-11-01                                               7.80
# 1990-12-01                                               7.61
#
#             Average Price of Electricity to Ultimate Customers, Commercial
# Month
# 1989-02-01                                                NaN
# 1989-03-01                                                NaN
# 1989-04-01                                                NaN
# 1989-05-01                                                NaN
# 1989-06-01                                                NaN
# 1989-07-01                                                NaN
# 1989-08-01                                                NaN
# 1989-09-01                                                NaN
# 1989-10-01                                                NaN
# 1989-11-01                                                NaN
# 1989-12-01                                                NaN
# 1990-01-01                                               6.93
# 1990-02-01                                               7.15
# 1990-03-01                                               7.23
# 1990-04-01                                               7.20
# 1990-05-01                                               7.31
# 1990-06-01                                               7.49
# 1990-07-01                                               7.52
# 1990-08-01                                               7.53
# 1990-09-01                                               7.50
# 1990-10-01                                               7.58
# 1990-11-01                                               7.34
# 1990-12-01                                               7.17

# %% [markdown]
# NaN values end 1989-12-1, so take values beyond 1990

# %%
df98 = df98[df98.index > '1990']
df98
# Out:
#             Average Price of Electricity to Ultimate Customers, Residential  \
# Month
# 1990-02-01                                               7.48
# 1990-03-01                                               7.57
# 1990-04-01                                               7.69
# 1990-05-01                                               7.96
# 1990-06-01                                               8.10
# ...                                                       ...
# 2024-05-01                                              16.43
# 2024-06-01                                              16.42
# 2024-07-01                                              16.63
# 2024-08-01                                              16.63
# 2024-09-01                                              16.83
#
#             Average Price of Electricity to Ultimate Customers, Commercial
# Month
# 1990-02-01                                               7.15
# 1990-03-01                                               7.23
# 1990-04-01                                               7.20
# 1990-05-01                                               7.31
# 1990-06-01                                               7.49
# ...                                                       ...
# 2024-05-01                                              12.48
# 2024-06-01                                              13.07
# 2024-07-01                                              13.58
# 2024-08-01                                              13.39
# 2024-09-01                                              13.47
#
# [416 rows x 2 columns]

# %%
df98.plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# If needed later we can truncate df43 to values after 1990 as well.

# %% [markdown]
# Final dataframes

# %%
df98.plot()
df43.plot()
plt.show()

# %% [markdown]
# ## __Save Data__

# %%
df43.to_csv(datapath + 'df43.csv')
df98.to_csv(datapath + 'df98.csv')
